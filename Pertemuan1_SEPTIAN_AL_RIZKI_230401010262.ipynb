# %% [markdown]
# <a href="https://colab.research.google.com/github/noone878/data-science-2026/blob/main/Pertemuan1_SEPTIAN_AL_RIZKI_230401010262.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAMA  : SEPTIAN AL RIZKI
# NIM   : 230401010262
# KELAS : IF 401

# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "SEPTIAN AL RIZKI" # String
prodi = "Teknik Informatika" # String
angkatan = 2023 # Integer
ipk = 3.55 # Float
aktif = True # Boolean
print(f"Nama : {nama}")
print(f"Prodi : {prodi}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : SEPTIAN AL RIZKI
# Prodi : Teknik Informatika
# Angkatan: 2023
# IPK : 3.55
# Aktif : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Jupyter", "Pandas", "Scikit-Learn", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    # Baris ini WAJIB menjorok ke dalam karena berada di dalam perulangan 'for'
    print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Jupyter
#  3. Pandas
#  4. Scikit-Learn
#  5. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan, ipk):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    # Baris ini WAJIB menjorok ke dalam (1 Tab)
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}, ipk {ipk}"

# Baris ini di luar fungsi, jadi kembali sejajar ke kiri
hasil = perkenalan( nama , prodi , angkatan, ipk)
print(hasil)
# Out:
# Hai! Saya SEPTIAN AL RIZKI dari Teknik Informatika, angkatan 2023, ipk 3.55
